# %%
import os
import plaid
import requests
import datetime
import json
import pandas as pd
# %matplotlib inline

# %%
def pretty_print_response(response):
  print(json.dumps(response, indent=4, sort_keys=True))

# %%
PLAID_CLIENT_ID = os.getenv('PLAID_CLIENT_ID')
# PLAID_SECRET = os.getenv('PLAID_SECRET')
PLAID_PUBLIC_KEY = os.getenv('PLAID_PUBLIC_KEY')
# PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
# PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')
PLAID_SBX_KEY = os.getenv('PLAID_SBX_KEY')

# %%
# Test if API keys are properly loaded in by using 'type'-function and see if it returns string

type(os.getenv('PLAID_CLIENT_ID'))
type(os.getenv('PLAID_PUBLIC_KEY'))
type(os.getenv('PLAID_SBX_KEY'))
# Out:
# str

# %% [markdown]
# # Plaid Access Token
#
# In this section, you will use the plaid-python api to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
# 1. Create a client to connect to plaid
# 2. Use the client to generate a public token and request the following items:
# ['transactions', 'income', 'assets']
# 3. Exchange the public token for an access token
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
INSTITUTION_ID = "ins_109508"

# %%
# YOUR CODE HERE

# Create client object
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SBX_KEY, public_key=PLAID_PUBLIC_KEY, environment='sandbox')

# Get institutions to see if client was properly created
client.Institutions.get(2)
# Out:
# {'institutions': [{'country_codes': ['US'],
#    'credentials': [{'label': 'Username', 'name': 'username', 'type': 'text'},
#     {'label': 'Password', 'name': 'password', 'type': 'password'}],
#    'has_mfa': True,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_112060',
#    'mfa': ['code', 'list', 'questions', 'selections'],
#    'mfa_code_type': 'numeric',
#    'name': '1st Bank (Broadus, MT) - Personal',
#    'oauth': False,
#    'products': ['assets',
#     'auth',
#     'balance',
#     'transactions',
#     'income',
#     'identity'],
#    'routing_numbers': []},
#   {'country_codes': ['US'],
#    'credentials': [{'label': 'Username', 'name': 'username', 'type': 'text'},
#     {'label': 'Password', 'name': 'password', 'type': 'password'}],
#    'has_mfa': True,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_112062',
#    'mfa': ['code', 'list', 'questions', 'selections'],
#    'mfa_code_type': 'numeric',
#    'name': '1st Constitution Bank - Personal',
# ...

# %% [markdown]
# ### 2. Generate a public token

# %%
# YOUR CODE HERE

# Select an institution for processing
INSTITUTION_ID = "ins_109508"

# Create public token to be exchanged for institution access token
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# YOUR CODE HERE

# Exchange public token for access token
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])

# Store access token as variable
access_token = exchange_response['access_token']

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# YOUR CODE HERE
client.Accounts.get(access_token)
# Out:
# {'accounts': [{'account_id': 'jBn7Wkz6deUmVg75b9RqCELjMNBMaAU1qK5jL',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': '77DXKLkNjJUBGxAZ8v6qSrLXw4owqBugLbWap',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': 'elWwpynDrqIq19PyoG7WC38lGkEGJ5UL1vNXm',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
# 2. Print the categories for each transaction type
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# YOUR CODE HERE

# Get transactions response
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now()) 
transactions_response = client.Transactions.get(access_token, start_date, end_date)

# Format the the provided JSON data with indents 
print(json.dumps(transactions_response, indent=4))
# Out:
# {
#     "accounts": [
#         {
#             "account_id": "jBn7Wkz6deUmVg75b9RqCELjMNBMaAU1qK5jL",
#             "balances": {
#                 "available": 100,
#                 "current": 110,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "0000",
#             "name": "Plaid Checking",
#             "official_name": "Plaid Gold Standard 0% Interest Checking",
#             "subtype": "checking",
#             "type": "depository"
#         },
#         {
#             "account_id": "77DXKLkNjJUBGxAZ8v6qSrLXw4owqBugLbWap",
#             "balances": {
#                 "available": 200,
#                 "current": 210,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "1111",
#             "name": "Plaid Saving",
# ...

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# YOUR CODE HERE

# Iterate and parse JSON response
for transactions in transactions_response['transactions']:
    categories = transactions['category']                      # could also use indexing ['category'][0] to only grab first label
    print(json.dumps(f" Categories for each transaction: {categories}", indent=4, sort_keys=True))
# Out:
# " Categories for each transaction: ['Payment', 'Credit Card']"
# " Categories for each transaction: ['Travel', 'Taxi']"
# " Categories for each transaction: ['Transfer', 'Debit']"
# " Categories for each transaction: ['Transfer', 'Deposit']"
# " Categories for each transaction: ['Recreation', 'Gyms and Fitness Centers']"
# " Categories for each transaction: ['Travel', 'Airlines and Aviation Services']"
# " Categories for each transaction: ['Food and Drink', 'Restaurants', 'Fast Food']"
# " Categories for each transaction: ['Food and Drink', 'Restaurants', 'Coffee Shop']"
# " Categories for each transaction: ['Food and Drink', 'Restaurants']"
# " Categories for each transaction: ['Transfer', 'Credit']"
# " Categories for each transaction: ['Travel', 'Airlines and Aviation Services']"
# " Categories for each transaction: ['Travel', 'Taxi']"
# " Categories for each transaction: ['Food and Drink', 'Restaurants']"
# " Categories for each transaction: ['Payment']"
# ...

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: date, name, amount, category.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# YOUR CODE HERE
transactions_df = pd.DataFrame(transactions_response['transactions'], columns=['date','name','amount', 'category'])

# Make sure to only use first category label in list by using str function
transactions_df['category'] = transactions_df['category'].str[0]

# set date to date time
transactions_df['date'] = pd.to_datetime(transactions_df['date'])

# set index to date
transactions_df = transactions_df.set_index('date')

# sort date index
transactions_df.sort_index(inplace=True)
transactions_df
# Out:
#                                              name   amount        category
# date
# 2020-03-25              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-03-25                                    KFC   500.00  Food and Drink
# 2020-03-25                   Madison Bicycle Shop   500.00           Shops
# 2020-03-26                             Tectra Inc   500.00  Food and Drink
# 2020-03-29                                   Uber     6.33          Travel
# 2020-03-31                        United Airlines   500.00          Travel
# 2020-04-10                           INTRST PYMNT    -4.22        Transfer
# 2020-04-11                               SparkFun    89.40  Food and Drink
# 2020-04-12                             McDonald's    12.00  Food and Drink
# 2020-04-12                              Starbucks     4.33  Food and Drink
# 2020-04-13                    Touchstone Climbing    78.50      Recreation
# ...

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# YOUR CODE HERE

# check current dtypes with the dtypes function
transactions_df.dtypes
# Out:
# name         object
# amount      float64
# category     object
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
# 1. Determine the previous year's gross income and print the results
# 2. Determine the current monthly income and print the results
# 3. Determine the projected yearly income and print the results

# %%
# YOUR CODE HERE

# Get income response with income.get as explained in Plaid documentation
income_response = client.Income.get(access_token)

# Format the the provided JSON data with indents to make data more readable
print(json.dumps(income_response, indent=4))
# Out:
# {
#     "income": {
#         "income_streams": [
#             {
#                 "confidence": 0.99,
#                 "days": 720,
#                 "monthly_income": 500,
#                 "name": "UNITED AIRLINES"
#             }
#         ],
#         "last_year_income": 6000,
#         "last_year_income_before_tax": 7285,
#         "max_number_of_overlapping_income_streams": 1,
#         "number_of_income_streams": 1,
#         "projected_yearly_income": 6085,
#         "projected_yearly_income_before_tax": 7389
#     },
#     "request_id": "hxaeGXLfMvxMYWn"
# }

# %%
# previous year's gross income

previous_year_gross_income = income_response['income']['last_year_income_before_tax']
print(f"Previous year's gross income was: ${previous_year_gross_income}")
# Out:
# Previous year's gross income was: $7285

# %%
# print current monthly income

current_monthly_income = income_response['income']['income_streams'][0]['monthly_income']
print(f"Current monthly income is: ${current_monthly_income}")
# Out:
# Current monthly income is: $500

# %%
# print projected yearly income (after tax)
projected_yearly_income = income_response['income']['projected_yearly_income']
print(f"Projected yearly income is: ${projected_yearly_income}")
# Out:
# Projected yearly income is: $6085

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
# 2. Generate a bar chart with the number of transactions for each category
# 3. Calculate the expenses per month
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
transactions_df
# Out:
#                                              name   amount        category
# date
# 2020-03-25              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-03-25                                    KFC   500.00  Food and Drink
# 2020-03-25                   Madison Bicycle Shop   500.00           Shops
# 2020-03-26                             Tectra Inc   500.00  Food and Drink
# 2020-03-29                                   Uber     6.33          Travel
# 2020-03-31                        United Airlines   500.00          Travel
# 2020-04-10                           INTRST PYMNT    -4.22        Transfer
# 2020-04-11                               SparkFun    89.40  Food and Drink
# 2020-04-12                             McDonald's    12.00  Food and Drink
# 2020-04-12                              Starbucks     4.33  Food and Drink
# 2020-04-13                    Touchstone Climbing    78.50      Recreation
# ...

# %%
# YOUR CODE HERE

# option 1
category_group = transactions_df.groupby(['category']).agg("sum")

#option 2
#category_group = transactions_df.groupby(['category']).sum()  

category_group
# Out:
#                  amount
# category
# Food and Drink  1105.73
# Payment         2103.50
# Recreation        78.50
# Shops            500.00
# Transfer        6845.78
# Travel            11.73

# %%
# Visualize category data in pie chart

category_group.plot(kind='pie', x='category', y='amount', title="Spending per category")

# %%
# Bar chart with number of transactions for each category

number_transactions_category_group = transactions_df.groupby(['category'])['category'].count()  
number_transactions_category_group.plot(kind='bar',title="Number of transactions per category")

# %% [markdown]
# ### Calculate the expenses per month

# %%
# YOUR CODE HERE

month_groupby = transactions_df.groupby(by=[transactions_df.index.month]).sum()
month_groupby
# Out:
#        amount
# date
# 3     4084.83
# 4     6560.41

# %%
# plot results

monthly_expenses_plot = month_groupby.plot(kind='bar', title="Expenses per month")

# set x-ax so it represents months

monthly_expenses_plot.set_xlabel('month')
# Out:
# Text(0.5, 0, 'month')
